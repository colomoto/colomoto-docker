# %%
import maboss

# %%
masim = maboss.load("Four_cycle.bnd", "Four_cycle_FEscape.cfg")

# %%
#maboss.wg_set_istate(masim)
simul = maboss.simulations["c57d57cc-7ea0-46dd-942f-e7af48305858"]
nodes = ('A', 'B')
istate = [0, 1]
for nd in nodes:
    simul.network.set_istate(nd, istate)

# %%
fast_res.plot_trajectory()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
slow_sim = fast_sim.copy()

# %%
slow_sim.param["$escape"] = 0.00001

# %%
slow_res = slow_sim.run()

# %%
slow_res.plot_trajectory()
